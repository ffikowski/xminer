# %%
import pandas as pd
from pathlib import Path
import yaml

# --- Load parameters.yml (same file the pipelines use) ---
PARAMS_FILE = Path("C:/Users/felix/Documents/xminer/src/xminer/config/parameters.yml")
assert PARAMS_FILE.exists(), f"parameters.yml not found: {PARAMS_FILE}"

with PARAMS_FILE.open("r", encoding="utf-8") as f:
    params = yaml.safe_load(f) or {}

YEAR = int(params.get("year", 2025))
MONTH = int(params.get("month", 12))
YM = f"{YEAR:04d}{MONTH:02d}"

STAND_TEXT = f"Erhoben für {MONTH:02d}/{YEAR}"  # << das nutzt der Plot

GRAPHICS_BASE_DIR = Path(
    params.get(
        "graphics_base_dir",
        r"C:/Users/felix/Documents/xminer/outputs",
    )
)

GRAPHICS_DIR = GRAPHICS_BASE_DIR / YM / "graphics"
GRAPHICS_DIR.mkdir(parents=True, exist_ok=True)

# %%
month = "12"
year = "2025"

trends_path = Path(f'C:/Users/felix/Documents/xminer/outputs/{year}{month}/trends/x_trends_{year}{month}.csv')
assert trends_path.exists(), f"File not found: {trends_path}"

df_trends = pd.read_csv(trends_path, low_memory=False)
df_trends.head()
# Out:
#       woeid place_name   trend_name  tweet_count  rank  \
# 0  23424829    Germany       Advent      53378.0     1
# 1  23424829    Germany  Wochenstart          NaN     2
# 2  23424829    Germany      #Gießen      39296.0     3
# 3  23424829    Germany     #Giessen      39268.0     4
# 4  23424829    Germany       Antifa      69637.0     5
#
#                        retrieved_at source_version
# 0  2025-12-01 07:00:03.179267+00:00             v2
# 1  2025-12-01 07:00:03.179267+00:00             v2
# 2  2025-12-01 07:00:03.179267+00:00             v2
# 3  2025-12-01 07:00:03.179267+00:00             v2
# 4  2025-12-01 07:00:03.179267+00:00             v2

# %%
# Build the dataframe
df_trend_counts = (
    df_trends["trend_name"]
    .value_counts()
    .head(10)
    .rename_axis("Trend Name")
    .reset_index(name="Anzahl")
)

df_trend_counts = df_trend_counts.rename(columns={"Trend Name": "Trend\nName", "Anzahl": "Anzahl\n(Count)"})


df_trend_counts.index = range(1, len(df_trend_counts) + 1)


# Trends to highlight
HIGHLIGHT_TRENDS = {
    "Meinungsfreiheit",
    "Zensur",
    "HateAid",
    "Feuerwerk",
    "Europe",
}

def color_trends(row):
    if row["Trend\nName"] in HIGHLIGHT_TRENDS:
        return ["background-color: #ffcccc; color: #000000"] * len(row)
    return [""] * len(row)

df_trend_counts_style = (
    df_trend_counts
    .style
    .apply(color_trends, axis=1)
)

df_trend_counts_style
# Out:
# <style type="text/css">
# #T_38700 th {
#   white-space: pre-line;
# }
# #T_38700_row2_col0, #T_38700_row2_col1, #T_38700_row3_col0, #T_38700_row3_col1, #T_38700_row5_col0, #T_38700_row5_col1, #T_38700_row8_col0, #T_38700_row8_col1, #T_38700_row9_col0, #T_38700_row9_col1 {
#   background-color: #ffcccc;
#   color: #000000;
# }
# </style>
# <table id="T_38700">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38700_level0_col0" class="col_heading level0 col0" >Trend
# Name</th>
#       <th id="T_38700_level0_col1" class="col_heading level0 col1" >Anzahl
# (Count)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38700_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_38700_row0_col0" class="data row0 col0" >#dasperfektedinner</td>
#       <td id="T_38700_row0_col1" class="data row0 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_38700_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_38700_row1_col0" class="data row1 col0" >Christmas</td>
#       <td id="T_38700_row1_col1" class="data row1 col1" >39</td>
#     </tr>
#     <tr>
#       <th id="T_38700_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_38700_row2_col0" class="data row2 col0" >Meinungsfreiheit</td>
#       <td id="T_38700_row2_col1" class="data row2 col1" >34</td>
#     </tr>
#     <tr>
#       <th id="T_38700_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_38700_row3_col0" class="data row3 col0" >Zensur</td>
#       <td id="T_38700_row3_col1" class="data row3 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_38700_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_38700_row4_col0" class="data row4 col0" >Advent</td>
#       <td id="T_38700_row4_col1" class="data row4 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_38700_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_38700_row5_col0" class="data row5 col0" >HateAid</td>
#       <td id="T_38700_row5_col1" class="data row5 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_38700_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_38700_row6_col0" class="data row6 col0" >Frohe Weihnachten</td>
#       <td id="T_38700_row6_col1" class="data row6 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_38700_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_38700_row7_col0" class="data row7 col0" >Wochenstart</td>
#       <td id="T_38700_row7_col1" class="data row7 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_38700_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_38700_row8_col0" class="data row8 col0" >Feuerwerk</td>
#       <td id="T_38700_row8_col1" class="data row8 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_38700_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_38700_row9_col0" class="data row9 col0" >Europe</td>
#       <td id="T_38700_row9_col1" class="data row9 col1" >24</td>
#     </tr>
#   </tbody>
# </table>

# %%
month = "12"
year = "2025"

base_path = Path(f'C:/Users/felix/Documents/xminer/data/politicians_{month}.csv')
assert base_path.exists(), f'File not found: {base_path}'

df_politicians = pd.read_csv(base_path, low_memory=False, sep=';')

print("Shape:", df_politicians.shape)
# Out:
# Shape: (632, 32)

# %%
title = df_politicians['AKAD_TITEL'].astype('string').fillna('').str.strip()
first = df_politicians['VORNAME'].astype('string').fillna('').str.strip().str.split().str[0]
last  = df_politicians['NACHNAME'].astype('string').fillna('').str.strip()

df_politicians['FULLNAME'] = (title + ' ' + first + ' ' + last).str.split().str.join(' ')

# %%
base_path = Path(f'C:/Users/felix/Documents/xminer/outputs/{year}{month}/tweets/tweets_{year}{month}.csv')
assert base_path.exists(), f'File not found: {base_path}'

df_tweets = pd.read_csv(base_path, low_memory=False)

# Parse datetime columns if present
for col in ['created_at', 'retrieved_at']:
    if col in df_tweets.columns:
        df_tweets[col] = pd.to_datetime(df_tweets[col], utc=True, errors='coerce')

print("Shape:", df_tweets.shape)

df_tweets = df_tweets.merge(
    df_politicians[['USERNAME', 'FULLNAME', 'PARTEI_KURZ']],
    right_on='USERNAME',
    left_on='username',
    how='left'
)


UNION_MAP = {"CDU": "CDU/CSU", "CSU": "CDU/CSU"}

def normalize_party(df: pd.DataFrame) -> pd.DataFrame:
    if "PARTEI_KURZ" in df.columns:
        df["PARTEI_KURZ"] = (
            df["PARTEI_KURZ"]
            .astype(str)
            .str.strip()
            .str.upper()
            .replace(UNION_MAP)
        )
    return df

df_tweets = normalize_party(df_tweets)
df_tweets.PARTEI_KURZ.value_counts()
# Out:
# Shape: (8529, 19)
# PARTEI_KURZ
# AFD                      4830
# BÜNDNIS 90/DIE GRÜNEN    1442
# CDU/CSU                  1167
# DIE LINKE.                809
# SPD                       281
# Name: count, dtype: int64

# %%
df_tweets.head()
# Out:
#               tweet_id            author_id         username  \
# 0  1995281744342446453           1412287272     AfDProtschka
# 1  1995282899185320085           1412287272     AfDProtschka
# 2  1995296477669679302  1690037692866686976        AArpaschi
# 3  1995354270393045350  1640320419474337794  ThomasF70168477
# 4  1995354300306870644  1640320419474337794  ThomasF70168477
#
#                  created_at  \
# 0 2025-12-01 00:00:13+00:00
# 1 2025-12-01 00:04:48+00:00
# 2 2025-12-01 00:58:45+00:00
# 3 2025-12-01 04:48:24+00:00
# 4 2025-12-01 04:48:31+00:00
#
#                                                 text lang  \
# 0    @julius__boehm Deren Kunde. Sind unsere Wähler.   de
# 1  @FamUnt Ihre Kunden sind zum Großteil unsere W...   de
# 2   Genau so machen wir das! https://t.co/Qq5OhUs7CW   de
# 3  RT @Birgit_Kelle: Erinnern sich alle an Avery ...   de
# 4  RT @Birgit_Kelle: Dies Land wird nicht durch I...   de
#
#        conversation_id  in_reply_to_user_id  possibly_sensitive  like_count  \
# 0  1995204308154163339         9.696286e+17               False           1
# 1  1995184775129113032         7.154709e+07               False         185
# 2  1995296477669679302                  NaN               False           5
# 3  1995354270393045350                  NaN               False           0
# 4  1995354300306870644                  NaN               False           0
#
#    ...  quote_count  bookmark_count  impression_count  source  \
# 0  ...            0               0                39     NaN
# 1  ...            0               1              1112     NaN
# 2  ...            0               0               120     NaN
# 3  ...            0               0                 0     NaN
# 4  ...            0               0                 0     NaN
#
#                                             entities  \
# 0  {'mentions': [{'id': '969628633819213824', 'en...
# 1  {'mentions': [{'id': '71547087', 'end': 7, 'st...
# 2  {'urls': [{'end': 48, 'url': 'https://t.co/Qq5...
# 3  {'mentions': [{'id': '782067510', 'end': 16, '...
# 4  {'mentions': [{'id': '782067510', 'end': 16, '...
#
#                                    referenced_tweets  \
# 0  [{'id': 1995204308154163339, 'type': 'replied_...
# 1  [{'id': 1995184775129113032, 'type': 'replied_...
# 2    [{'id': 1995111205753475283, 'type': 'quoted'}]
# 3  [{'id': 1995192847461474424, 'type': 'retweete...
# 4  [{'id': 1995231554147389765, 'type': 'retweete...
#
#                       retrieved_at         USERNAME            FULLNAME  \
# 0 2025-12-03 02:37:51.362875+00:00     AfDProtschka   Stephan Protschka
# 1 2025-12-03 02:37:51.362873+00:00     AfDProtschka   Stephan Protschka
# 2 2025-12-03 08:53:18.082250+00:00        AArpaschi  Alexander Arpaschi
# 3 2025-12-03 08:38:18.693550+00:00  ThomasF70168477       Thomas Fetsch
# 4 2025-12-03 08:38:18.693547+00:00  ThomasF70168477       Thomas Fetsch
#
#   PARTEI_KURZ
# 0         AFD
# 1         AFD
# 2         AFD
# 3         AFD
# 4         AFD
#
# [5 rows x 22 columns]

# %%
PARTY_COLORS = {
    "CDU/CSU": "#000000",
    "CDU": "#000000",
    "CSU": "#000000",
    "SPD": "#E3000F",
    "GRÜNE": "#1AA64A",
    "BÜNDNIS 90/DIE GRÜNEN": "#1AA64A",
    "BÜNDNIS 90/DIE GRÜNEN": "#1AA64A",
    "DIE GRÜNEN": "#1AA64A",
    "DIE LINKE.": "#BE3075",
    "LINKE": "#BE3075",
    "FDP": "#FFED00",
    "AFD": "#009EE0",
    "BSW": "#009688",
    "FW": "#F28F00",
    "SSW": "#00A3E0",
    "PIRATEN": "#FF8800",
    "PARTEI": "#9E9E9E",
    "ÖDP": "#FF6A00",
    "OEDP": "#FF6A00",
}

dfs = []

for term in ["Meinungsfreiheit", "Zensur", "HateAid", "Feuerwerk", "Europe"]:
    df_filtered = df_tweets[df_tweets["text"].str.contains(term, na=False)]

    counts = (
        df_filtered.groupby("PARTEI_KURZ")
        .size()
        .rename(f"Anzahl\n\"{term}\"\nPosts")
        .reset_index()
    )

    def color_party(row):
        color = PARTY_COLORS.get(row["PARTEI_KURZ"], "")
        return [f"background-color: {color}"] * len(row) if color else [""] * len(row)

    counts_style = counts.style.apply(color_party, axis=1)
    
    dfs.append(counts)

counts_total = (
    df_tweets.groupby("PARTEI_KURZ")
    .size()
    .rename("Anzahl\nPosts\nInsgesamt")
    .reset_index()
)

dfs_merged = []

for df in dfs:
    df = df.merge(counts_total, on="PARTEI_KURZ", how="left")
    df = df.rename(columns={"PARTEI_KURZ": "Partei"})
    df["Partei"] = df["Partei"].replace({"BÜNDNIS 90/DIE GRÜNEN": "DIE GRÜNEN"})
    dfs_merged.append(df)

dfs_styled = []

for df in dfs_merged:
    # df = df.rename(columns={"PARTEI_KURZ": "Partei"})
    def color_party(row):
        color = PARTY_COLORS.get(row["Partei"], "")
        return [f"background-color: {color}"] * len(row) if color else [""] * len(row)
    
    df_style = (
        df
        .style
        .apply(color_party, axis=1)
        .set_table_styles([
    {"selector": "th", "props": [
        ("white-space", "pre-line"),
        ("text-align", "center"),
        ("vertical-align", "middle"),
    ]}
])
)   

    dfs_styled.append(df_style)

# %%
for df_style in dfs_styled:
    display(df_style)
# Out:
# <style type="text/css">
# #T_9d496 th {
#   white-space: pre-line;
#   text-align: center;
#   vertical-align: middle;
# }
# #T_9d496_row0_col0, #T_9d496_row0_col1, #T_9d496_row0_col2 {
#   background-color: #009EE0;
# }
# #T_9d496_row1_col0, #T_9d496_row1_col1, #T_9d496_row1_col2 {
#   background-color: #1AA64A;
# }
# #T_9d496_row2_col0, #T_9d496_row2_col1, #T_9d496_row2_col2 {
#   background-color: #000000;
# }
# #T_9d496_row3_col0, #T_9d496_row3_col1, #T_9d496_row3_col2 {
#   background-color: #BE3075;
# }
# #T_9d496_row4_col0, #T_9d496_row4_col1, #T_9d496_row4_col2 {
#   background-color: #E3000F;
# }
# </style>
# <table id="T_9d496">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d496_level0_col0" class="col_heading level0 col0" >Partei</th>
#       <th id="T_9d496_level0_col1" class="col_heading level0 col1" >Anzahl
# "Meinungsfreiheit"
# Posts</th>
#       <th id="T_9d496_level0_col2" class="col_heading level0 col2" >Anzahl
# Posts
# Insgesamt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d496_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d496_row0_col0" class="data row0 col0" >AFD</td>
#       <td id="T_9d496_row0_col1" class="data row0 col1" >41</td>
#       <td id="T_9d496_row0_col2" class="data row0 col2" >4830</td>
#     </tr>
#     <tr>
#       <th id="T_9d496_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9d496_row1_col0" class="data row1 col0" >DIE GRÜNEN</td>
#       <td id="T_9d496_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_9d496_row1_col2" class="data row1 col2" >1442</td>
#     </tr>
#     <tr>
#       <th id="T_9d496_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9d496_row2_col0" class="data row2 col0" >CDU/CSU</td>
#       <td id="T_9d496_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_9d496_row2_col2" class="data row2 col2" >1167</td>
#     </tr>
#     <tr>
#       <th id="T_9d496_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9d496_row3_col0" class="data row3 col0" >DIE LINKE.</td>
#       <td id="T_9d496_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_9d496_row3_col2" class="data row3 col2" >809</td>
#     </tr>
#     <tr>
#       <th id="T_9d496_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9d496_row4_col0" class="data row4 col0" >SPD</td>
#       <td id="T_9d496_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_9d496_row4_col2" class="data row4 col2" >281</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f2352 th {
#   white-space: pre-line;
#   text-align: center;
#   vertical-align: middle;
# }
# #T_f2352_row0_col0, #T_f2352_row0_col1, #T_f2352_row0_col2 {
#   background-color: #009EE0;
# }
# #T_f2352_row1_col0, #T_f2352_row1_col1, #T_f2352_row1_col2 {
#   background-color: #1AA64A;
# }
# #T_f2352_row2_col0, #T_f2352_row2_col1, #T_f2352_row2_col2 {
#   background-color: #000000;
# }
# #T_f2352_row3_col0, #T_f2352_row3_col1, #T_f2352_row3_col2 {
#   background-color: #BE3075;
# }
# #T_f2352_row4_col0, #T_f2352_row4_col1, #T_f2352_row4_col2 {
#   background-color: #E3000F;
# }
# </style>
# <table id="T_f2352">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2352_level0_col0" class="col_heading level0 col0" >Partei</th>
#       <th id="T_f2352_level0_col1" class="col_heading level0 col1" >Anzahl
# "Zensur"
# Posts</th>
#       <th id="T_f2352_level0_col2" class="col_heading level0 col2" >Anzahl
# Posts
# Insgesamt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2352_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2352_row0_col0" class="data row0 col0" >AFD</td>
#       <td id="T_f2352_row0_col1" class="data row0 col1" >34</td>
#       <td id="T_f2352_row0_col2" class="data row0 col2" >4830</td>
#     </tr>
#     <tr>
#       <th id="T_f2352_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f2352_row1_col0" class="data row1 col0" >DIE GRÜNEN</td>
#       <td id="T_f2352_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_f2352_row1_col2" class="data row1 col2" >1442</td>
#     </tr>
#     <tr>
#       <th id="T_f2352_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f2352_row2_col0" class="data row2 col0" >CDU/CSU</td>
#       <td id="T_f2352_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_f2352_row2_col2" class="data row2 col2" >1167</td>
#     </tr>
#     <tr>
#       <th id="T_f2352_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f2352_row3_col0" class="data row3 col0" >DIE LINKE.</td>
#       <td id="T_f2352_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_f2352_row3_col2" class="data row3 col2" >809</td>
#     </tr>
#     <tr>
#       <th id="T_f2352_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f2352_row4_col0" class="data row4 col0" >SPD</td>
#       <td id="T_f2352_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_f2352_row4_col2" class="data row4 col2" >281</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d563c th {
#   white-space: pre-line;
#   text-align: center;
#   vertical-align: middle;
# }
# #T_d563c_row0_col0, #T_d563c_row0_col1, #T_d563c_row0_col2 {
#   background-color: #009EE0;
# }
# #T_d563c_row1_col0, #T_d563c_row1_col1, #T_d563c_row1_col2 {
#   background-color: #1AA64A;
# }
# #T_d563c_row2_col0, #T_d563c_row2_col1, #T_d563c_row2_col2 {
#   background-color: #000000;
# }
# #T_d563c_row3_col0, #T_d563c_row3_col1, #T_d563c_row3_col2 {
#   background-color: #BE3075;
# }
# #T_d563c_row4_col0, #T_d563c_row4_col1, #T_d563c_row4_col2 {
#   background-color: #E3000F;
# }
# </style>
# <table id="T_d563c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d563c_level0_col0" class="col_heading level0 col0" >Partei</th>
#       <th id="T_d563c_level0_col1" class="col_heading level0 col1" >Anzahl
# "HateAid"
# Posts</th>
#       <th id="T_d563c_level0_col2" class="col_heading level0 col2" >Anzahl
# Posts
# Insgesamt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d563c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d563c_row0_col0" class="data row0 col0" >AFD</td>
#       <td id="T_d563c_row0_col1" class="data row0 col1" >48</td>
#       <td id="T_d563c_row0_col2" class="data row0 col2" >4830</td>
#     </tr>
#     <tr>
#       <th id="T_d563c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d563c_row1_col0" class="data row1 col0" >DIE GRÜNEN</td>
#       <td id="T_d563c_row1_col1" class="data row1 col1" >13</td>
#       <td id="T_d563c_row1_col2" class="data row1 col2" >1442</td>
#     </tr>
#     <tr>
#       <th id="T_d563c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d563c_row2_col0" class="data row2 col0" >CDU/CSU</td>
#       <td id="T_d563c_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_d563c_row2_col2" class="data row2 col2" >1167</td>
#     </tr>
#     <tr>
#       <th id="T_d563c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d563c_row3_col0" class="data row3 col0" >DIE LINKE.</td>
#       <td id="T_d563c_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_d563c_row3_col2" class="data row3 col2" >809</td>
#     </tr>
#     <tr>
#       <th id="T_d563c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d563c_row4_col0" class="data row4 col0" >SPD</td>
#       <td id="T_d563c_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_d563c_row4_col2" class="data row4 col2" >281</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f8098 th {
#   white-space: pre-line;
#   text-align: center;
#   vertical-align: middle;
# }
# #T_f8098_row0_col0, #T_f8098_row0_col1, #T_f8098_row0_col2 {
#   background-color: #009EE0;
# }
# #T_f8098_row1_col0, #T_f8098_row1_col1, #T_f8098_row1_col2 {
#   background-color: #1AA64A;
# }
# #T_f8098_row2_col0, #T_f8098_row2_col1, #T_f8098_row2_col2 {
#   background-color: #BE3075;
# }
# </style>
# <table id="T_f8098">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8098_level0_col0" class="col_heading level0 col0" >Partei</th>
#       <th id="T_f8098_level0_col1" class="col_heading level0 col1" >Anzahl
# "Feuerwerk"
# Posts</th>
#       <th id="T_f8098_level0_col2" class="col_heading level0 col2" >Anzahl
# Posts
# Insgesamt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8098_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8098_row0_col0" class="data row0 col0" >AFD</td>
#       <td id="T_f8098_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_f8098_row0_col2" class="data row0 col2" >4830</td>
#     </tr>
#     <tr>
#       <th id="T_f8098_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8098_row1_col0" class="data row1 col0" >DIE GRÜNEN</td>
#       <td id="T_f8098_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_f8098_row1_col2" class="data row1 col2" >1442</td>
#     </tr>
#     <tr>
#       <th id="T_f8098_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f8098_row2_col0" class="data row2 col0" >DIE LINKE.</td>
#       <td id="T_f8098_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_f8098_row2_col2" class="data row2 col2" >809</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7716b th {
#   white-space: pre-line;
#   text-align: center;
#   vertical-align: middle;
# }
# #T_7716b_row0_col0, #T_7716b_row0_col1, #T_7716b_row0_col2 {
#   background-color: #009EE0;
# }
# #T_7716b_row1_col0, #T_7716b_row1_col1, #T_7716b_row1_col2 {
#   background-color: #1AA64A;
# }
# #T_7716b_row2_col0, #T_7716b_row2_col1, #T_7716b_row2_col2 {
#   background-color: #000000;
# }
# #T_7716b_row3_col0, #T_7716b_row3_col1, #T_7716b_row3_col2 {
#   background-color: #BE3075;
# }
# #T_7716b_row4_col0, #T_7716b_row4_col1, #T_7716b_row4_col2 {
#   background-color: #E3000F;
# }
# </style>
# <table id="T_7716b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7716b_level0_col0" class="col_heading level0 col0" >Partei</th>
#       <th id="T_7716b_level0_col1" class="col_heading level0 col1" >Anzahl
# "Europe"
# Posts</th>
#       <th id="T_7716b_level0_col2" class="col_heading level0 col2" >Anzahl
# Posts
# Insgesamt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7716b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7716b_row0_col0" class="data row0 col0" >AFD</td>
#       <td id="T_7716b_row0_col1" class="data row0 col1" >15</td>
#       <td id="T_7716b_row0_col2" class="data row0 col2" >4830</td>
#     </tr>
#     <tr>
#       <th id="T_7716b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7716b_row1_col0" class="data row1 col0" >DIE GRÜNEN</td>
#       <td id="T_7716b_row1_col1" class="data row1 col1" >11</td>
#       <td id="T_7716b_row1_col2" class="data row1 col2" >1442</td>
#     </tr>
#     <tr>
#       <th id="T_7716b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7716b_row2_col0" class="data row2 col0" >CDU/CSU</td>
#       <td id="T_7716b_row2_col1" class="data row2 col1" >32</td>
#       <td id="T_7716b_row2_col2" class="data row2 col2" >1167</td>
#     </tr>
#     <tr>
#       <th id="T_7716b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7716b_row3_col0" class="data row3 col0" >DIE LINKE.</td>
#       <td id="T_7716b_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_7716b_row3_col2" class="data row3 col2" >809</td>
#     </tr>
#     <tr>
#       <th id="T_7716b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7716b_row4_col0" class="data row4 col0" >SPD</td>
#       <td id="T_7716b_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_7716b_row4_col2" class="data row4 col2" >281</td>
#     </tr>
#   </tbody>
# </table>

# %%
PARTY_COLORS = {
    "CDU/CSU": "#000000",
    "CDU": "#000000",
    "CSU": "#000000",
    "SPD": "#E3000F",
    "GRÜNE": "#1AA64A",
    "BÜNDNIS 90/DIE GRÜNEN": "#1AA64A",
    "DIE GRÜNEN": "#1AA64A",
    "DIE LINKE.": "#BE3075",
    "LINKE": "#BE3075",
    "FDP": "#FFED00",
    "AFD": "#009EE0",
    "BSW": "#009688",
    "FW": "#F28F00",
    "SSW": "#00A3E0",
    "PIRATEN": "#FF8800",
    "PARTEI": "#9E9E9E",
    "ÖDP": "#FF6A00",
    "OEDP": "#FF6A00",
}

TREND_TRANSLATIONS = {
    "Meinungsfreiheit": "Freedom of speech",
    "Zensur": "Censorship",
    "HateAid": "HateAid",
    "Feuerwerk": "Fireworks",
    "Europe": "Europe",
}

dfs = []

for term in ["Meinungsfreiheit", "Zensur", "HateAid", "Feuerwerk", "Europe"]:
    df_filtered = df_tweets[df_tweets["text"].str.contains(term, na=False)]

    term_en = TREND_TRANSLATIONS.get(term, term)
    col_name = f'Count\n"{term}"\n({term_en})\nPosts'

    counts = (
        df_filtered.groupby("PARTEI_KURZ")
        .size()
        .rename(col_name)
        .reset_index()
    )

    def color_party(row):
        color = PARTY_COLORS.get(row["PARTEI_KURZ"], "")
        return [f"background-color: {color}"] * len(row) if color else [""] * len(row)

    counts_style = counts.style.apply(color_party, axis=1)

    dfs.append(counts)

counts_total = (
    df_tweets.groupby("PARTEI_KURZ")
    .size()
    .rename("Count\nTotal\nPosts")
    .reset_index()
)

dfs_merged = []

for df in dfs:
    df = df.merge(counts_total, on="PARTEI_KURZ", how="left")
    df = df.rename(columns={"PARTEI_KURZ": "Party"})
    df["Party"] = df["Party"].replace({"BÜNDNIS 90/DIE GRÜNEN": "DIE GRÜNEN"})
    dfs_merged.append(df)

dfs_styled = []

for df in dfs_merged:
    def color_party(row):
        color = PARTY_COLORS.get(row["Party"], "")
        return [f"background-color: {color}"] * len(row) if color else [""] * len(row)

    df_style = (
        df
        .style
        .apply(color_party, axis=1)
        .set_table_styles([
            {"selector": "th", "props": [
                ("white-space", "pre-line"),
                ("text-align", "center"),
                ("vertical-align", "middle"),
            ]}
        ])
    )

    dfs_styled.append(df_style)

# %%
for df_style in dfs_styled:
    display(df_style)
# Out:
# <style type="text/css">
# #T_5decf th {
#   white-space: pre-line;
#   text-align: center;
#   vertical-align: middle;
# }
# #T_5decf_row0_col0, #T_5decf_row0_col1, #T_5decf_row0_col2 {
#   background-color: #009EE0;
# }
# #T_5decf_row1_col0, #T_5decf_row1_col1, #T_5decf_row1_col2 {
#   background-color: #1AA64A;
# }
# #T_5decf_row2_col0, #T_5decf_row2_col1, #T_5decf_row2_col2 {
#   background-color: #000000;
# }
# #T_5decf_row3_col0, #T_5decf_row3_col1, #T_5decf_row3_col2 {
#   background-color: #BE3075;
# }
# #T_5decf_row4_col0, #T_5decf_row4_col1, #T_5decf_row4_col2 {
#   background-color: #E3000F;
# }
# </style>
# <table id="T_5decf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5decf_level0_col0" class="col_heading level0 col0" >Party</th>
#       <th id="T_5decf_level0_col1" class="col_heading level0 col1" >Count
# "Meinungsfreiheit"
# (Freedom of speech)
# Posts</th>
#       <th id="T_5decf_level0_col2" class="col_heading level0 col2" >Count
# Total
# Posts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5decf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5decf_row0_col0" class="data row0 col0" >AFD</td>
#       <td id="T_5decf_row0_col1" class="data row0 col1" >41</td>
#       <td id="T_5decf_row0_col2" class="data row0 col2" >4830</td>
#     </tr>
#     <tr>
#       <th id="T_5decf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5decf_row1_col0" class="data row1 col0" >DIE GRÜNEN</td>
#       <td id="T_5decf_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_5decf_row1_col2" class="data row1 col2" >1442</td>
#     </tr>
#     <tr>
#       <th id="T_5decf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5decf_row2_col0" class="data row2 col0" >CDU/CSU</td>
#       <td id="T_5decf_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_5decf_row2_col2" class="data row2 col2" >1167</td>
#     </tr>
#     <tr>
#       <th id="T_5decf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5decf_row3_col0" class="data row3 col0" >DIE LINKE.</td>
#       <td id="T_5decf_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_5decf_row3_col2" class="data row3 col2" >809</td>
#     </tr>
#     <tr>
#       <th id="T_5decf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5decf_row4_col0" class="data row4 col0" >SPD</td>
#       <td id="T_5decf_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_5decf_row4_col2" class="data row4 col2" >281</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_eef2f th {
#   white-space: pre-line;
#   text-align: center;
#   vertical-align: middle;
# }
# #T_eef2f_row0_col0, #T_eef2f_row0_col1, #T_eef2f_row0_col2 {
#   background-color: #009EE0;
# }
# #T_eef2f_row1_col0, #T_eef2f_row1_col1, #T_eef2f_row1_col2 {
#   background-color: #1AA64A;
# }
# #T_eef2f_row2_col0, #T_eef2f_row2_col1, #T_eef2f_row2_col2 {
#   background-color: #000000;
# }
# #T_eef2f_row3_col0, #T_eef2f_row3_col1, #T_eef2f_row3_col2 {
#   background-color: #BE3075;
# }
# #T_eef2f_row4_col0, #T_eef2f_row4_col1, #T_eef2f_row4_col2 {
#   background-color: #E3000F;
# }
# </style>
# <table id="T_eef2f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eef2f_level0_col0" class="col_heading level0 col0" >Party</th>
#       <th id="T_eef2f_level0_col1" class="col_heading level0 col1" >Count
# "Zensur"
# (Censorship)
# Posts</th>
#       <th id="T_eef2f_level0_col2" class="col_heading level0 col2" >Count
# Total
# Posts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eef2f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eef2f_row0_col0" class="data row0 col0" >AFD</td>
#       <td id="T_eef2f_row0_col1" class="data row0 col1" >34</td>
#       <td id="T_eef2f_row0_col2" class="data row0 col2" >4830</td>
#     </tr>
#     <tr>
#       <th id="T_eef2f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eef2f_row1_col0" class="data row1 col0" >DIE GRÜNEN</td>
#       <td id="T_eef2f_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_eef2f_row1_col2" class="data row1 col2" >1442</td>
#     </tr>
#     <tr>
#       <th id="T_eef2f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eef2f_row2_col0" class="data row2 col0" >CDU/CSU</td>
#       <td id="T_eef2f_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_eef2f_row2_col2" class="data row2 col2" >1167</td>
#     </tr>
#     <tr>
#       <th id="T_eef2f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eef2f_row3_col0" class="data row3 col0" >DIE LINKE.</td>
#       <td id="T_eef2f_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_eef2f_row3_col2" class="data row3 col2" >809</td>
#     </tr>
#     <tr>
#       <th id="T_eef2f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eef2f_row4_col0" class="data row4 col0" >SPD</td>
#       <td id="T_eef2f_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_eef2f_row4_col2" class="data row4 col2" >281</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b4465 th {
#   white-space: pre-line;
#   text-align: center;
#   vertical-align: middle;
# }
# #T_b4465_row0_col0, #T_b4465_row0_col1, #T_b4465_row0_col2 {
#   background-color: #009EE0;
# }
# #T_b4465_row1_col0, #T_b4465_row1_col1, #T_b4465_row1_col2 {
#   background-color: #1AA64A;
# }
# #T_b4465_row2_col0, #T_b4465_row2_col1, #T_b4465_row2_col2 {
#   background-color: #000000;
# }
# #T_b4465_row3_col0, #T_b4465_row3_col1, #T_b4465_row3_col2 {
#   background-color: #BE3075;
# }
# #T_b4465_row4_col0, #T_b4465_row4_col1, #T_b4465_row4_col2 {
#   background-color: #E3000F;
# }
# </style>
# <table id="T_b4465">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4465_level0_col0" class="col_heading level0 col0" >Party</th>
#       <th id="T_b4465_level0_col1" class="col_heading level0 col1" >Count
# "HateAid"
# (HateAid)
# Posts</th>
#       <th id="T_b4465_level0_col2" class="col_heading level0 col2" >Count
# Total
# Posts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4465_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b4465_row0_col0" class="data row0 col0" >AFD</td>
#       <td id="T_b4465_row0_col1" class="data row0 col1" >48</td>
#       <td id="T_b4465_row0_col2" class="data row0 col2" >4830</td>
#     </tr>
#     <tr>
#       <th id="T_b4465_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b4465_row1_col0" class="data row1 col0" >DIE GRÜNEN</td>
#       <td id="T_b4465_row1_col1" class="data row1 col1" >13</td>
#       <td id="T_b4465_row1_col2" class="data row1 col2" >1442</td>
#     </tr>
#     <tr>
#       <th id="T_b4465_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b4465_row2_col0" class="data row2 col0" >CDU/CSU</td>
#       <td id="T_b4465_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_b4465_row2_col2" class="data row2 col2" >1167</td>
#     </tr>
#     <tr>
#       <th id="T_b4465_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b4465_row3_col0" class="data row3 col0" >DIE LINKE.</td>
#       <td id="T_b4465_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_b4465_row3_col2" class="data row3 col2" >809</td>
#     </tr>
#     <tr>
#       <th id="T_b4465_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b4465_row4_col0" class="data row4 col0" >SPD</td>
#       <td id="T_b4465_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_b4465_row4_col2" class="data row4 col2" >281</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cdc2b th {
#   white-space: pre-line;
#   text-align: center;
#   vertical-align: middle;
# }
# #T_cdc2b_row0_col0, #T_cdc2b_row0_col1, #T_cdc2b_row0_col2 {
#   background-color: #009EE0;
# }
# #T_cdc2b_row1_col0, #T_cdc2b_row1_col1, #T_cdc2b_row1_col2 {
#   background-color: #1AA64A;
# }
# #T_cdc2b_row2_col0, #T_cdc2b_row2_col1, #T_cdc2b_row2_col2 {
#   background-color: #BE3075;
# }
# </style>
# <table id="T_cdc2b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdc2b_level0_col0" class="col_heading level0 col0" >Party</th>
#       <th id="T_cdc2b_level0_col1" class="col_heading level0 col1" >Count
# "Feuerwerk"
# (Fireworks)
# Posts</th>
#       <th id="T_cdc2b_level0_col2" class="col_heading level0 col2" >Count
# Total
# Posts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdc2b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cdc2b_row0_col0" class="data row0 col0" >AFD</td>
#       <td id="T_cdc2b_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_cdc2b_row0_col2" class="data row0 col2" >4830</td>
#     </tr>
#     <tr>
#       <th id="T_cdc2b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cdc2b_row1_col0" class="data row1 col0" >DIE GRÜNEN</td>
#       <td id="T_cdc2b_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_cdc2b_row1_col2" class="data row1 col2" >1442</td>
#     </tr>
#     <tr>
#       <th id="T_cdc2b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cdc2b_row2_col0" class="data row2 col0" >DIE LINKE.</td>
#       <td id="T_cdc2b_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_cdc2b_row2_col2" class="data row2 col2" >809</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c43d8 th {
#   white-space: pre-line;
#   text-align: center;
#   vertical-align: middle;
# }
# #T_c43d8_row0_col0, #T_c43d8_row0_col1, #T_c43d8_row0_col2 {
#   background-color: #009EE0;
# }
# #T_c43d8_row1_col0, #T_c43d8_row1_col1, #T_c43d8_row1_col2 {
#   background-color: #1AA64A;
# }
# #T_c43d8_row2_col0, #T_c43d8_row2_col1, #T_c43d8_row2_col2 {
#   background-color: #000000;
# }
# #T_c43d8_row3_col0, #T_c43d8_row3_col1, #T_c43d8_row3_col2 {
#   background-color: #BE3075;
# }
# #T_c43d8_row4_col0, #T_c43d8_row4_col1, #T_c43d8_row4_col2 {
#   background-color: #E3000F;
# }
# </style>
# <table id="T_c43d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c43d8_level0_col0" class="col_heading level0 col0" >Party</th>
#       <th id="T_c43d8_level0_col1" class="col_heading level0 col1" >Count
# "Europe"
# (Europe)
# Posts</th>
#       <th id="T_c43d8_level0_col2" class="col_heading level0 col2" >Count
# Total
# Posts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c43d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c43d8_row0_col0" class="data row0 col0" >AFD</td>
#       <td id="T_c43d8_row0_col1" class="data row0 col1" >15</td>
#       <td id="T_c43d8_row0_col2" class="data row0 col2" >4830</td>
#     </tr>
#     <tr>
#       <th id="T_c43d8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c43d8_row1_col0" class="data row1 col0" >DIE GRÜNEN</td>
#       <td id="T_c43d8_row1_col1" class="data row1 col1" >11</td>
#       <td id="T_c43d8_row1_col2" class="data row1 col2" >1442</td>
#     </tr>
#     <tr>
#       <th id="T_c43d8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c43d8_row2_col0" class="data row2 col0" >CDU/CSU</td>
#       <td id="T_c43d8_row2_col1" class="data row2 col1" >32</td>
#       <td id="T_c43d8_row2_col2" class="data row2 col2" >1167</td>
#     </tr>
#     <tr>
#       <th id="T_c43d8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c43d8_row3_col0" class="data row3 col0" >DIE LINKE.</td>
#       <td id="T_c43d8_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_c43d8_row3_col2" class="data row3 col2" >809</td>
#     </tr>
#     <tr>
#       <th id="T_c43d8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c43d8_row4_col0" class="data row4 col0" >SPD</td>
#       <td id="T_c43d8_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_c43d8_row4_col2" class="data row4 col2" >281</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_style
df_renamed = df_style.rename(columns={"Trend Name": "Trend\nName", "Anzahl": "Anzahl\n(Count)"})

df_renamed.style.set_table_styles([
    {"selector": "th", "props": [("white-space", "pre-line")]}
])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 2
#       1 df_style
# ----> 2 df_renamed = df_style.rename(columns={"Trend Name": "Trend\nName", "Anzahl": "Anzahl\n(Count)"})
#       4 df_renamed.style.set_table_styles([
#       5     {"selector": "th", "props": [("white-space", "pre-line")]}
#       6 ])
#
# AttributeError: 'Styler' object has no attribute 'rename'

# %%
from xminer.utils.utils_plots import (
        plot_party_hbar,
        plot_party_stack_tweets_engagement,
        plot_party_pie_pct,
        STAND_TEXT,
        GRAPHICS_DIR,
    )
