# %%
import pandas as pd
from pathlib import Path

base_path = Path('C:/Users/felix/Documents/xminer/data/politicians_09.csv')
assert base_path.exists(), f'File not found: {base_path}'

df_politicians = pd.read_csv(base_path, low_memory=False, sep=';')

print("Shape:", df_politicians.shape)
df_politicians.head(10)
# Out:
# Shape: (632, 32)
#    KEY_COLUMN        ID GEBURTSDATUM     GEBURTSORT  GEBURTSLAND  STERBEDATUM  \
# 0           1  11000756   16.01.1948         Berlin  Deutschland          NaN
# 1           2  11002718   18.02.1961         Aachen  Deutschland          NaN
# 2           3  11002720   19.01.1968         Dessau  Deutschland          NaN
# 3           4  11002733   09.06.1961         Lorsch  Deutschland          NaN
# 4           5  11002735   11.11.1955         Brilon  Deutschland          NaN
# 5           6  11002735   11.11.1955         Brilon  Deutschland          NaN
# 6           7  11002754   17.05.1962          Düren  Deutschland          NaN
# 7           8  11002765   02.07.1965     Meckenheim  Deutschland          NaN
# 8           9  11003034   31.03.1958      Stralsund  Deutschland          NaN
# 9          10  11003132   03.05.1966  Friedrichroda  Deutschland          NaN
#
#   GESCHLECHT          FAMILIENSTAND            RELIGION  \
# 0   männlich   geschieden, 3 Kinder      konfessionslos
# 1   männlich  verheiratet, 3 Kinder  römisch-katholisch
# 2   weiblich     geschieden, 1 Kind                 NaN
# 3   männlich  verheiratet, 2 Kinder         evangelisch
# 4   männlich  verheiratet, 3 Kinder  römisch-katholisch
# 5   männlich  verheiratet, 3 Kinder  römisch-katholisch
# 6   männlich    verheiratet, 1 Kind         evangelisch
# 7   männlich  verheiratet, 3 Kinder          katholisch
# 8   männlich   geschieden, 2 Kinder                 NaN
# 9   weiblich  verpartnert, 2 Kinder         evangelisch
#
#                         BERUF  ... WP_WP WP_MDBWP_VON  WP_MDBWP_BIS  \
# 0                Rechtsanwalt  ...  21.0   25.03.2025           NaN
# 1     Ministerpräsident a. D.  ...  21.0   25.03.2025           NaN
# 2      Dipl.-Agraringenieurin  ...  21.0   25.03.2025           NaN
# 3          Dipl.-Mathematiker  ...  21.0   25.03.2025           NaN
# 4                Rechtsanwalt  ...  21.0   25.03.2025           NaN
# 5                Rechtsanwalt  ...  21.0   25.03.2025           NaN
# 6      Politikwissenschaftler  ...  21.0   25.03.2025           NaN
# 7                Rechtsanwalt  ...  21.0   25.03.2025           NaN
# 8  Wirtschaftswissenschaftler  ...  21.0   25.03.2025           NaN
# 9                         MdB  ...  21.0   25.03.2025           NaN
#
#   WP_WKR_NUMMER                         WP_WKR_NAME WP_WKR_LAND WP_LISTE  \
# 0          83.0             Berlin-Treptow-Köpenick          BE       BE
# 1          86.0                            Aachen I          NW       NW
# 2          70.0        Anhalt – Dessau – Wittenberg          ST       ST
# 3         187.0                          Bergstraße          HE       HE
# 4         146.0                  Hochsauerlandkreis          NW       NW
# 5         146.0                  Hochsauerlandkreis          NW       NW
# 6          89.0                               Düren          NW       NW
# 7          97.0                 Rhein-Sieg-Kreis II          NW       NW
# 8          14.0      Rostock – Landkreis Rostock II          MV       MV
# 9         192.0  Erfurt – Weimar – Weimarer Land II          TH       TH
#
#   WP_MANDATSART WP_INSTITUTIONEN         USERNAME
# 0    Direktwahl                        GregorGysi
# 1    Direktwahl                      ArminLaschet
# 2   Landesliste                               NaN
# 3    Direktwahl                   meister_schafft
# 4    Direktwahl                    _FriedrichMerz
# 5    Direktwahl                     bundeskanzler
# 6    Direktwahl                     _ThomasRachel
# 7    Direktwahl                        n_roettgen
# 8   Landesliste                    DietmarBartsch
# 9   Landesliste                    GoeringEckardt
#
# [10 rows x 32 columns]

# %%
base_path = Path('C:/Users/felix/Documents/xminer/outputs/202509/profiles/individual_base_202509.csv')
assert base_path.exists(), f'File not found: {base_path}'

df_profiles = pd.read_csv(base_path, low_memory=False)

# Parse datetime columns if present
for col in ['created_at', 'retrieved_at']:
    if col in df_profiles.columns:
        df_profiles[col] = pd.to_datetime(df_profiles[col], utc=True, errors='coerce')

print("Shape:", df_profiles.shape)
df_profiles.head(10)
# Out:
# Shape: (441, 15)
#           username                     name partei_kurz  verified  protected  \
# 0     Alice_Weidel             Alice Weidel         AFD     False      False
# 1  Beatrix_vStorch       Beatrix von Storch         AFD     False      False
# 2   Tino_Chrupalla           Tino Chrupalla         AFD     False      False
# 3          KrahMax  Dr. Maximilian Krah MdB         AFD      True      False
# 4   GottfriedCurio      Dr. Gottfried Curio         AFD     False      False
# 5    MalteKaufmann   Dr. Malte Kaufmann MdB         AFD     False      False
# 6   Martin_Sichert      Martin Sichert, MdB         AFD     False      False
# 7       GtzFrmming       Götz Frömming, MdB         AFD     False      False
# 8    Rene_Springer            René Springer         AFD     False      False
# 9  M_Reichardt_AfD    Martin Reichardt, MdB         AFD     False      False
#
#    followers_count  following_count  tweet_count  listed_count  \
# 0          1188211              610         5282          1935
# 1           251474             1071        13279           969
# 2           206936              373         1631           610
# 3            92410              944        42074           484
# 4            72228             2561          800           266
# 5            62627             2775        11371           294
# 6            37831              237         2287           253
# 7            35872             3046        24150           271
# 8            34802              990         6518           167
# 9            32920             2614        12036           206
#
#    account_age_days  followers_per_day  follow_ratio  followers_per_tweet  \
# 0            3175.0         374.239685   1947.886885           224.954752
# 1            4803.0          52.357693    234.802988            18.937721
# 2            3275.0          63.186565    554.788204           126.876763
# 3            4646.0          19.890228     97.891949             2.196368
# 4            3133.0          23.053942     28.203046            90.285000
# 5            5796.0          10.805210     22.568288             5.507607
# 6            2940.0          12.867687    159.624473            16.541758
# 7            4801.0           7.471777     11.776756             1.485383
# 8            3180.0          10.944025     35.153535             5.339368
# 9            4166.0           7.902064     12.593726             2.735128
#
#                  created_at                     retrieved_at
# 0 2017-02-19 19:29:51+00:00 2025-10-01 15:40:01.839205+00:00
# 1 2012-09-05 20:19:14+00:00 2025-10-01 15:40:01.839202+00:00
# 2 2016-11-11 18:02:05+00:00 2025-10-01 15:40:01.838892+00:00
# 3 2013-02-09 13:06:11+00:00 2025-10-01 15:40:02.795134+00:00
# 4 2017-04-02 19:31:49+00:00 2025-10-01 15:40:01.838893+00:00
# 5 2009-12-17 21:33:30+00:00 2025-10-01 15:40:02.401125+00:00
# 6 2017-10-12 09:19:55+00:00 2025-10-01 15:40:01.839194+00:00
# 7 2012-09-08 00:53:26+00:00 2025-10-01 15:40:01.839007+00:00
# 8 2017-02-14 16:33:18+00:00 2025-10-01 15:40:01.839195+00:00
# 9 2014-06-04 10:26:57+00:00 2025-10-01 15:40:01.839045+00:00

# %%
df_profiles = (
    df_profiles
        .assign(__key=df_profiles['username'].astype(str).str.strip().str.lower())
        .merge(
            df_politicians
                .assign(__key=df_politicians['USERNAME'].astype(str).str.strip().str.lower())[
                    ['AKAD_TITEL', 'VORNAME', 'NACHNAME', '__key']
                ],
            on='__key',
            how='left'
        )
        .drop(columns='__key')
)

# %%
title = df_profiles['AKAD_TITEL'].astype('string').fillna('').str.strip()
first = df_profiles['VORNAME'].astype('string').fillna('').str.strip().str.split().str[0]
last  = df_profiles['NACHNAME'].astype('string').fillna('').str.strip()

df_profiles['FULLNAME'] = (title + ' ' + first + ' ' + last).str.split().str.join(' ')

# %%
df_profiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   username             441 non-null    object
#  1   name                 441 non-null    object
#  2   partei_kurz          441 non-null    object
#  3   verified             441 non-null    bool
#  4   protected            441 non-null    bool
#  5   followers_count      441 non-null    int64
#  6   following_count      441 non-null    int64
#  7   tweet_count          441 non-null    int64
#  8   listed_count         441 non-null    int64
#  9   account_age_days     441 non-null    float64
#  10  followers_per_day    441 non-null    float64
#  11  follow_ratio         431 non-null    float64
#  12  followers_per_tweet  432 non-null    float64
#  13  created_at           441 non-null    datetime64[ns, UTC]
#  14  retrieved_at         441 non-null    datetime64[ns, UTC]
#  15  AKAD_TITEL           75 non-null     object
#  16  VORNAME              441 non-null    object
#  17  NACHNAME             441 non-null    object
#  18  FULLNAME             441 non-null    object
# dtypes: bool(2), datetime64[ns, UTC](2), float64(4), int64(4), object(7)
# memory usage: 59.6+ KB

# %%
num = df_profiles.select_dtypes(include=['number'])
num.describe().T.sort_values('mean', ascending=False)
# Out:
#                      count          mean           std    min          25%  \
# followers_count      441.0  22208.217687  96766.897717    0.0   919.000000
# tweet_count          441.0   4471.226757   8469.087860    0.0   259.000000
# account_age_days     441.0   3579.469388   1798.557132  125.0  2266.000000
# following_count      441.0    834.519274    982.188769    0.0   177.000000
# follow_ratio         431.0    251.828705   4124.569319    0.0     2.327438
# listed_count         441.0    172.625850    333.840372    0.0    19.000000
# followers_per_tweet  432.0     12.473307     56.538427    0.0     1.080877
# followers_per_day    441.0      7.533586     41.669546    0.0     0.307692
#
#                              50%          75%           max
# followers_count      2880.000000  9443.000000  1.195174e+06
# tweet_count          1498.000000  5117.000000  8.121200e+04
# account_age_days     3638.000000  5028.000000  6.296000e+03
# following_count       555.000000  1091.000000  9.010000e+03
# follow_ratio            5.586826    13.140942  8.545400e+04
# listed_count           81.000000   170.000000  3.149000e+03
# followers_per_tweet     2.483252     5.789241  9.494889e+02
# followers_per_day       0.906600     2.693851  6.565873e+02

# %%
vc = df_profiles.get('partei_kurz')
vc.value_counts(dropna=False).to_frame('count') if vc is not None else 'partei_kurz missing'
# Out:
#                        count
# partei_kurz
# CDU/CSU                  132
# AFD                      123
# SPD                       81
# BÜNDNIS 90/DIE GRÜNEN     65
# DIE LINKE.                39
# SSW                        1

# %%
cols2 = [c for c in ['username','name','partei_kurz','followers_count','following_count','tweet_count','follow_ratio','followers_per_tweet'] if c in df_profiles.columns]

top_ratio = (df_profiles.sort_values('follow_ratio', ascending=False, na_position='last')[cols2].head(20)
             if 'follow_ratio' in df_profiles.columns else 'follow_ratio missing')

top_fpt = (df_profiles.sort_values('followers_per_tweet', ascending=False, na_position='last')[cols2].head(20)
           if 'followers_per_tweet' in df_profiles.columns else 'followers_per_tweet missing')

top_ratio
# Out:
#             username                          name partei_kurz  \
# 364      EskenSaskia                  Saskia Esken         SPD
# 320       GregorGysi                   Gregor Gysi  DIE LINKE.
# 359  Karl_Lauterbach         Prof. Karl Lauterbach         SPD
# 0       Alice_Weidel                  Alice Weidel         AFD
# 188   _FriedrichMerz                Friedrich Merz     CDU/CSU
# 70    JoernKoenigAfD               Jörn König, MdB         AFD
# 193    bundeskanzler  Bundeskanzler Friedrich Merz     CDU/CSU
# 200      AussenMinDE               Johann Wadephul     CDU/CSU
# 2     Tino_Chrupalla                Tino Chrupalla         AFD
# 11        BrandnerSt          🇩🇪Stephan Brandner🇩🇪         AFD
# 360       OlafScholz                   Olaf Scholz         SPD
# 361      NancyFaeser                  Nancy Faeser         SPD
# 28   PeterBoehringer              Peter Boehringer         AFD
# 321   DietmarBartsch               Dietmar Bartsch  DIE LINKE.
# 189        jensspahn                    Jens Spahn     CDU/CSU
# 192   hendrikstreeck               Hendrik Streeck     CDU/CSU
# 1    Beatrix_vStorch            Beatrix von Storch         AFD
# 10    DrBerndBaumann             Dr. Bernd Baumann         AFD
# 190     ArminLaschet                 Armin Laschet     CDU/CSU
# 16       MatthiasMdb        Matthias Helferich MdB         AFD
#
#      followers_count  following_count  tweet_count  follow_ratio  \
# 364            85454                1           90  85454.000000
# 320           499820              124         3597   4030.806452
# 359          1195174              324        12418   3688.808642
# 0            1188211              610         5282   1947.886885
# 188           541778              455         3578   1190.720879
# 70              1184                1          434   1184.000000
# 193           124095              109          594   1138.486239
# 200            26781               47          204    569.808511
# 2             206936              373         1631    554.788204
# 11             29019               56         4490    518.196429
# 360           629741             1253         7045    502.586592
# 361           173925              383         2464    454.112272
# 28             10255               23         1783    445.869565
# 321            85919              196         9619    438.362245
# 189           271168              732        14958    370.448087
# 192           141527              499          686    283.621242
# 1             251474             1071        13279    234.802988
# 10             32638              149          384    219.046980
# 190           200727              995        16119    201.735678
# 16             20624              123         2482    167.674797
#
#      followers_per_tweet
# 364           949.488889
# 320           138.954684
# 359            96.245289
# 0             224.954752
# 188           151.419229
# 70              2.728111
# 193           208.914141
# 200           131.279412
# 2             126.876763
# 11              6.463029
# 360            89.388361
# 361            70.586445
# 28              5.751542
# 321             8.932217
# 189            18.128627
# 192           206.307580
# 1              18.937721
# 10             84.994792
# 190            12.452820
# 16              8.309428

# %%
def plot_party_hbar(
    df_profiles,
    y_col: str,  # e.g. "username"
    x_col: str,
    top_n: int = 10,
    party_col: str = "partei_kurz",
    title: str | None = None,
):
    import pandas as pd
    import plotly.graph_objects as go

    PARTY_COLORS = {
        "CDU/CSU": "#000000",
        "CDU": "#000000",
        "CSU": "#000000",
        "SPD": "#E3000F",
        "GRÜNE": "#1AA64A",
        "GRUENE": "#1AA64A",
        "B90/GRUENE": "#1AA64A",
        "DIE LINKE": "#BE3075",
        "LINKE": "#BE3075",
        "FDP": "#FFED00",
        "AFD": "#009EE0",
        "BSW": "#009688",
        "FW": "#F28F00",
        "SSW": "#00A3E0",
        "PIRATEN": "#FF8800",
        "PARTEI": "#9E9E9E",
        "ÖDP": "#FF6A00",
        "OEDP": "#FF6A00",
    }

    def _normalize_party_value(p: str) -> str:
        if p is None:
            return ""
        key = str(p).strip().upper()
        if key in {"CDU", "CSU"}:
            return "CDU/CSU"
        if key.startswith("GRÜN") or key.startswith("GRUEN") or "GRUENE" in key or "GRÜNE" in key or "B90" in key:
            return "GRÜNE"
        if key in {"LINKE", "DIE LINKE", "DIE LINKE."}:
            return "DIE LINKE"
        if key in {"ÖDP", "OEDP"}:
            return "ÖDP"
        if key in {"AFD", "ALTERNATIVE FÜR DEUTSCHLAND", "ALTERNATIVE FUER DEUTSCHLAND"}:
            return "AFD"
        return key

    def _resolve_party_colors(series: pd.Series) -> list[str]:
        parties = series.astype("string").fillna("")
        return [PARTY_COLORS.get(_normalize_party_value(p), "#888888") for p in parties]

    def _is_dark_color(hex_color: str) -> bool:
        """Determine if a color is dark based on brightness."""
        hex_color = hex_color.lstrip("#")
        r, g, b = tuple(int(hex_color[i:i+2], 16) for i in (0, 2, 4))
        brightness = (r * 299 + g * 587 + b * 114) / 1000
        return brightness < 140

    for col in (y_col, x_col):
        if col not in df_profiles.columns:
            raise ValueError(f"Missing required column: {col}")
    if "FULLNAME" not in df_profiles.columns:
        raise ValueError("Missing required column: FULLNAME")

    work = df_profiles.copy()
    if party_col not in work.columns:
        work[party_col] = None

    # --- NEW: create combined label for y-axis ---
    work["_label"] = work["FULLNAME"].astype(str).str.strip() + " (" + work[y_col].astype(str).str.strip() + ")"

    work = work.sort_values(x_col, ascending=False).head(top_n).copy()

    categories = work["_label"].tolist()[::-1]
    work["_y_cat"] = pd.Categorical(work["_label"], categories=categories, ordered=True)

    colors = _resolve_party_colors(work[party_col])

    # Decide whether each bar is short or long
    max_x = work[x_col].max()
    threshold = 0.15 * max_x
    text_positions = ["outside" if x < threshold else "inside" for x in work[x_col]]

    # Choose text colors: white for dark bars (inside), black otherwise
    text_colors = []
    for c, pos in zip(colors, text_positions):
        if pos == "outside":
            text_colors.append("#000000")
        else:
            text_colors.append("#FFFFFF" if _is_dark_color(c) else "#000000")

    fig = go.Figure(
        go.Bar(
            x=work[x_col],
            y=work["_y_cat"],
            orientation="h",
            marker_color=colors,
            text=[f"{v:,.0f}" for v in work[x_col]],
            textposition=text_positions,
            insidetextanchor="end",
            textfont=dict(color=text_colors),
            customdata=work[[party_col, y_col, "FULLNAME"]].astype(str).values,
            hovertemplate=(
                "Name: %{customdata[2]} (%{customdata[1]})<br>"
                f"{x_col}: %{{x:,.0f}}<br>"
                f"{party_col}: %{{customdata[0]}}<extra></extra>"
            ),
        )
    )

    fig.update_layout(
        title=title,
        title_x=0.5,
        xaxis_title=x_col,
        yaxis_title="",
        yaxis=dict(categoryorder="array", categoryarray=categories),
        bargap=0.25,
        margin=dict(l=10, r=40, t=40, b=10),
        height=max(300, 30 * len(work)),
    )

    fig.update_traces(cliponaxis=False, texttemplate="%{text}")
    return fig

# %%
plot_party_hbar(df_profiles, 'username', 'tweet_count', top_n=20, title='MdBs: Anzahl der Posts auf X')

# %%
plot_party_hbar(df_profiles, 'username', 'followers_count', top_n=20, title='MdBs: Anzahl Follower auf X')

# %%
plot_party_hbar(df_profiles[df_profiles["partei_kurz"]=="AFD"], 'name', 'followers_count', top_n=10, title='MdBs der AfD: Anzahl Follower auf X')

# %%
df_profiles.partei_kurz.unique()
# Out:
# array(['AFD', 'BÜNDNIS 90/DIE GRÜNEN', 'CDU/CSU', 'DIE LINKE.', 'SPD',
#        'SSW'], dtype=object)

# %%
plot_party_hbar(df_profiles[df_profiles["partei_kurz"]=='CDU/CSU'], 'name', 'followers_count', top_n=10, title='MdBs von CDU/CSU: Anzahl Follower auf X')

# %%
plot_party_hbar(df_profiles[df_profiles["partei_kurz"]=='BÜNDNIS 90/DIE GRÜNEN'], 'name', 'followers_count', top_n=10, title='MdBs von BÜNDNIS 90/DIE GRÜNEN: Anzahl Follower auf X')

# %%
party="DIE LINKE."
plot_party_hbar(
    df_profiles[df_profiles["partei_kurz"]==party], 
    'name', 
    'followers_count', 
    top_n=10, 
    title=f'MdBs der {party}: Anzahl Follower auf X'
)

# %%
plot_party_hbar(df_profiles[df_profiles["partei_kurz"]=="SPD"], 'name', 'followers_count', top_n=10, title='MdBs der SPD: Anzahl Follower auf X')

# %%
plot_party_hbar(
    df_profiles, 
    'name', 
    'followers_per_tweet', 
    top_n=15, 
    title=f'MdBs: Follower per Post auf X'
)
